# %%
MODEL_CLASS = "DACR"
DATA_NAME = "movielens"
MODEL_NAME = f"{MODEL_CLASS}_{DATA_NAME}"
LEARNING_TYPE = "pairwise"
TRN_NEG_PER_POS = 1
TRN_BATCH_SIZE = 256

# WORK_DIR_PATH = "../.."

from google.colab import drive
drive.mount('/content/drive')
WORK_DIR_PATH = "/content/drive/MyDrive/RS-DACR/"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Constants

# %%
# split
EVAL_NEG_PER_POS = 99
EVAL_BATCH_SIZE = 1000
DATA_LOADING_TYPE = "general"
FILTER_BY = "user"
TRN_VAL_TST_RATIO = [0.8, 0.1, 0.1]
NEG_PER_POS = [TRN_NEG_PER_POS, TRN_NEG_PER_POS, EVAL_NEG_PER_POS, EVAL_NEG_PER_POS]
BATCH_SIZE = [TRN_BATCH_SIZE, TRN_BATCH_SIZE, EVAL_BATCH_SIZE, EVAL_BATCH_SIZE]
MAX_HIST = None
SHUFFLE = False if DATA_LOADING_TYPE=="curriculum" else True

# Model
N_FACTORS = 32
HIDDEN_ARL = [N_FACTORS*4, N_FACTORS*2, N_FACTORS, N_FACTORS // 2]
HIDDEN_AML = [N_FACTORS*2, N_FACTORS*2, N_FACTORS, N_FACTORS // 2]
DROPOUT = 0.2

# how to learn
LEARNING_RATE = 1e-4 if TRN_BATCH_SIZE==256 else 1e-3
LAMBDA_ = 1e-3

# how to monitor
PATIENCE = 5
MIN_DELTA = 1e-3

# how to loop
N_EPOCHS = 1000
INTERVAL = 5

# %% [markdown]
# # Config

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(WORK_DIR_PATH)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: /content/drive/MyDrive/RS-DACR

# %%
import pandas as pd
import torch
from DACR import dacr
import UTILS
from LOOP.loop import TrainingLoop
from LOOP.monitor.predictor import predict
from LOOP.monitor.monitor import EarlyStoppingMonitor
from LOOP.metric.ranking import ndcg_at_k as metric_fn
from LOOP.metric.ranking import top_k_loop

# %%
if LEARNING_TYPE=="pairwise":
    from DATA_SPLITTER.pairwise import trn_val_tst
    from LOOP.trainer.pairwise import PairwiseTrainer as Trainer
    from LOOP.loss_fn.bpr import bpr as task_fn

elif LEARNING_TYPE=="pointwise":
    from DATA_SPLITTER.pointwise import trn_val_tst
    from LOOP.trainer.pointwise import PointwiseTrainer as Trainer
    from LOOP.loss_fn.bce import bce as task_fn

else:
    ValueError

# %%
from UTILS.constants import (
    DEFAULT_USER_COL,
    DEFAULT_ITEM_COL,
    DEFAULT_RATING_COL,
    DEFAULT_LABEL_COL,
    DEFAULT_TIMESTAMP_COL,
    DEFAULT_PREDICTION_COL,
    COL_DICT,
    DEFAULT_K,
    DEFAULT_THRESHOLD,
    SEED,
)

# %%
# seed
UTILS.seed.reset()
# Out:
# SETTING ALL SEEDS TO 42...
# ALL SEEDS SET

# %%
# Available GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Data Preparation

# %%
data = pd.read_csv(f"./_data/{DATA_NAME}.csv")

# %%
# Number of user, item
N_USERS = data[DEFAULT_USER_COL].nunique()
N_ITEMS = data[DEFAULT_ITEM_COL].nunique()

# %%
# data Description
UTILS.data_handler.description(data)
# Out:
# number of user: 610
# number of item: 9724
# total interaction: 100836
# interaction density: 1.7000 %
# max interaction of user: 2698
# top 10.0 % interaction of user: 400.3
# mean interaction of user: 165
# mean interaction of item: 10

# %%
kwargs = dict(
    origin=data,
    n_users=N_USERS,
    n_items=N_ITEMS,
    loading_type=DATA_LOADING_TYPE,
)

dataloader = trn_val_tst.DataSplitter(**kwargs)

# %%
kwargs = dict(
    filter_by=FILTER_BY,
    trn_val_tst_ratio=TRN_VAL_TST_RATIO,
    neg_per_pos=NEG_PER_POS,
    batch_size=BATCH_SIZE,
    max_hist=MAX_HIST,
    shuffle=SHUFFLE,
)

loaders, interactions, histories = dataloader.get(**kwargs)

# %%
trn_loader, val_loader, tst_loader, loo_loader = loaders

# %% [markdown]
# # Modeling

# %%
kwargs = dict(
    n_users=N_USERS,
    n_items=N_ITEMS,
    dropout=DROPOUT,
    interactions=interactions,
)

if MODEL_CLASS=="DACR":
    kwargs["n_factors"] = N_FACTORS
    kwargs["hidden_arl"] = HIDDEN_ARL
    kwargs["hidden_aml"] = HIDDEN_AML
    model = dacr.model.Module(**kwargs)
elif MODEL_CLASS=="AMLNet":
    kwargs["n_factors"] = N_FACTORS
    kwargs["hidden"] = HIDDEN_AML
    model = dacr.amlnet.Module(**kwargs)
elif MODEL_CLASS=="ARLNet":
    kwargs["hidden"] = HIDDEN_ARL
    model = dacr.arlnet.Module(**kwargs)
else:
    ValueError

# %%
kwargs = dict(
    model=model,
    task_fn=task_fn,
    lr=LEARNING_RATE,
    lambda_=LAMBDA_
)

trainer = Trainer(**kwargs)

# %%
kwargs = dict(
    model=model,
    metric_fn=metric_fn,
    patience=PATIENCE,
    min_delta=MIN_DELTA,
)

monitor = EarlyStoppingMonitor(**kwargs)

# %%
kwargs = dict(
    model=model,
    trainer=trainer,
    monitor=monitor,
)

loop = TrainingLoop(**kwargs)

# %% [markdown]
# # Train

# %%
kwargs = dict(
    trn_loader=trn_loader,
    val_loader=val_loader,
    loo_loader=loo_loader,
    n_epochs=N_EPOCHS,
    interval=INTERVAL,
)

history = loop.fit(**kwargs)
# Out:
# LEAVE ONE OUT BEST EPOCH: 160
# LEAVE ONE OUT BEST SCORE: 0.5836
# MEAN OF PER EPOCH (/s): 9.1968

# %%
UTILS.visualizer.loss_plot(history, 'TASK LOSS')

# %% [markdown]
# # Test

# %%
kwargs = dict(
    model=model,
    dataloader=tst_loader,
)

result = predict(**kwargs)
# Out:
# TST: 100%|██████████| 1003/1003 [00:09<00:00, 106.65it/s]

# %%
eval = top_k_loop(result)
eval
# Out:
#    top_k  hit_ratio  precision    recall       map      ndcg
# 0      5   0.826230   0.372131  0.290301  0.219253  0.450188
# 1     10   0.927869   0.293934  0.416205  0.268724  0.465754
# 2     15   0.968852   0.247541  0.496526  0.291858  0.482006
# 3     20   0.978689   0.214918  0.549719  0.304957  0.494037
# 4     25   0.988525   0.192787  0.591500  0.314294  0.504934
# 5     50   0.996721   0.129607  0.701487  0.333564  0.536257
# 6    100   1.000000   0.083607  0.796866  0.346083  0.568871

# %% [markdown]
# # Save

# %%
PATH = f'./_checkpoints/{LEARNING_TYPE}_{INTERVAL}_{TRN_BATCH_SIZE}/{MODEL_NAME}.pth'

kwargs = dict(
    model=model,
    path=PATH,
)

UTILS.checkpointer.save(**kwargs)
